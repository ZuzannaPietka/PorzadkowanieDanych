# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Zuza\Downloads\fortune500-full.csv',)
df.head(5)
# Out:
#    Year  Rank           Company  Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                 9823.5                  806
# 1  1955     2       Exxon Mobil                 5661.4                584.8
# 2  1955     3        U.S. Steel                 3250.4                195.4
# 3  1955     4  General Electric                 2959.1                212.6
# 4  1955     5            Esmark                 2510.8                 19.1

# %%
firma1 = df['Company']=='Esmark'
df1=df[firma1]
firma2 = df['Company']=='CBS'
df2=df[firma2]

# %%
x1=df1['Year']
y1= df1['Revenue (in millions)']
x2=df2['Year']
y2= df2['Revenue (in millions)']

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.legend(['Esmark','CBS'])
plt.xlabel('Year')
plt.ylabel('Revenue (in millions)')
# Out:
# Text(0, 0.5, 'Revenue (in millions)')
